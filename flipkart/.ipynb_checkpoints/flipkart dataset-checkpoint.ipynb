# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 10.5/10.5 MB 7.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 503.5/503.5 KB 7.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.6/14.6 MB 9.6 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.1 is available.
# You should consider upgrading via the 'C:\Users\DELL\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
dataset = pd.read_csv(r"C:\Users\DELL\Dropbox\My PC (DESKTOP-O27PNVO)\Downloads\flipkart_com-ecommerce_sample (1).csv")
dataset.dropna(inplace = True)
# print(dataset)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
# dataset.product_url

# %%
mainList = []
l = 0
for i in dataset.index:
    if "Clothing" in dataset["product_category_tree"][i]:
        #mainList.append(dataset[:][i])
        mainList.append(dataset.iloc[i:i+1])
        l += 1
flipkartprevious = []




for i in range(l):
#     print(mainList[i])
    str1 = mainList[i].product_url
    str2 = mainList[i]["product_name"]
    str3 = mainList[i]["retail_price"]
    str4 = mainList[i]["discounted_price"]
    str5 = mainList[i]["image"]
    str6 = mainList[i]["overall_rating"]
    str7 = mainList[i]["brand"]
    
    str1 = str1.to_string().split(" ")
    str2 = str2.to_string().split(" ")
    str3 = str3.to_string().split(" ")
    str4 = str4.to_string().split(" ")
    str5 = str5.to_string().split(" ")
    str6 = str6.to_string().split(" ")
    str7 = str7.to_string().split(" ")

    
    str1 = str1[1:]
    str2 = str2[1:]
    str3 = str3[1:]
    str4 = str4[1:]
    str5 = str5[1:]
    str6 = str6[1:]
    str7 = str7[1:]
    while "" in str1 :
        str1.remove("")
    while "" in str2 :
        str2.remove("")
    while "" in str1 :
        str1.remove("")
    while "" in str3 :
        str3.remove("")
    while "" in str4 :
        str4.remove("")
    while "" in str5 :
        str5.remove("")
    while "" in str6 :
        str6.remove("")
    while "" in str7 :
        str7.remove("")
    str1 = " ".join(str1)
    str2 = " ".join(str2)
    str3 = " ".join(str3)
    str4 = " ".join(str4)
    str5 = " ".join(str5)
    str6 = " ".join(str6)
    str7 = " ".join(str7)
    x = ''
    for i in str5 :
        x += i
    x = x.split(',')
    x = x[1:]
    if len(x) != 0 :
        x = x[0]
        x = x[1:]
        if(x[-1]==']') :
            x = x[:len(x)-1]
#         print(x)
        x = x[1:len(x)-1]
        flipkartprevious.append({'product_url':str1,'product_name':str2,'retail_price':str3,'discounted_price':str4,'image':x,'overall_rating':str6,'brand':str7})
# for i in flipkartprevious :
# #     print((i["overall_rating"]))
#     if  i["overall_rating"].isnumeric() == False:
#         flipkartprevious.remove(i)

print(flipkartprevious)
# Out:
# [{'product_url': 'http://www.flipkart.com/alisha-solid-women-s-cycling-shorts/p/itmeh2ffvzetthbb?pid=SRTEH2FF9KEDEFGF', 'product_name': "Alisha Solid Women's Cycling Shorts", 'retail_price': '999.0', 'discounted_price': '379.0', 'image': 'http://img5a.flixcart.com/image/short/p/j/z/altght4p-26-alisha-38-original-imaeh2d5kbufss6n.jpeg', 'overall_rating': '3.0', 'brand': 'Alisha'}, {'product_url': 'http://www.flipkart.com/alisha-solid-women-s-cycling-shorts/p/itmeh2f6sdgah2pq?pid=SRTEH2F6HUZMQ6SJ', 'product_name': "Alisha Solid Women's Cycling Shorts", 'retail_price': '699.0', 'discounted_price': '267.0', 'image': 'http://img6a.flixcart.com/image/short/p/h/t/altht-3p-1-alisha-34-original-imaeh2d5jxvh4msy.jpeg', 'overall_rating': '3.0', 'brand': 'Alisha'}, {'product_url': 'http://www.flipkart.com/alisha-solid-women-s-cycling-shorts/p/itmeh2ftwkzykhcg?pid=SRTEH2FVVKRBAXHB', 'product_name': "Alisha Solid Women's Cycling Shorts", 'retail_price': '1199.0', 'discounted_price': '479.0', 'imag
# ...

# %%
import pymongo
import certifi
ca=certifi.where()

client = pymongo.MongoClient("mongodb+srv://jayachandra:jayachandra@cluster0.uwku6.mongodb.net/?retryWrites=true&w=majority",tlsCAFile=ca)
db = client.flipkart
collection = db.flipkartadmindata


a = collection.delete_many({})
print(a.deleted_count)
# Out:
# 2206

# %%
for i in range(len(flipkartprevious)) :
    collection.insert_one(flipkartprevious[i])
